# %% [markdown]
# <a href="https://colab.research.google.com/github/monikatyagi01/YBI_project1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📦 Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset from GitHub
df = pd.read_csv('https://github.com/YBIFoundation/Pandas/raw/refs/heads/main/EcommerceEDA.csv')

#Preview First 5 Rows
print(df.head())

#Dataset Info
print("\nData Info:")
print(df.info())

#Summary Statistics
print("\nSummary Statistics:")
print(df.describe())

#Check Missing Values
print("\nMissing Values Count:")
print(df.isna().sum())

#Convert 'order_date' column to datetime (with error handling)
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

#Check again after conversion
print("\nData Info After Converting 'order_date':")
print(df.info())

#Fill missing values in 'price' column using median
median_price = df['price'].median()
df['price'].fillna(median_price, inplace=True)

#Fill missing values in 'quantity' column using median
median_quantity = df['quantity'].median()
df['quantity'].fillna(median_quantity, inplace=True)

#Drop rows with missing 'state' or 'order_date'
df.dropna(subset=['state', 'order_date'], inplace=True)

#Final check for missing values
print("\nRemaining Missing Values After Cleanup:")
print(df.isna().sum())

#Analysis Question:
# Which product categories generate the highest total sales, and how do they compare?

#Count of each category
print("\nCategory Value Counts:")
print(df['category'].value_counts())

#Total Sales by Category (ascending)
print("\nTotal Sales by Category:")
print(df.groupby('category')['total_price'].sum().sort_values())

#Total Sales by Region
print("\nTotal Sales by Region:")
print(df.groupby('region')['total_price'].sum())
# Out:
#    order_id customer_id        order_date   category     product    price  \
# 0      9543      N50867  01-06-2023 06:04  Groceries        Milk  1581.79
# 1      4597      S29121  09-06-2024 13:25     Beauty     Perfume  1347.40
# 2      4273      E16999  24-02-2023 21:16  Groceries      Fruits  1210.50
# 3      6810      W96167  26-12-2023 11:12  Groceries  Vegetables   896.23
# 4      2316      N48352  10-11-2024 00:13    Apparel      Jacket  1463.49
#
#    quantity  total_price           state region payment_method
# 0       5.0      7908.95       Rajasthan  North            UPI
# 1       5.0      6737.00  Andhra Pradesh  South     Debit Card
# 2       2.0      2421.00     West Bengal   East            UPI
# 3       5.0      4481.15  Madhya Pradesh   West         PayPal
# 4       2.0      2926.98   Uttar Pradesh  North     Debit Card
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 11 columns):
# ...
